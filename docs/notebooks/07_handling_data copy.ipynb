# %% [markdown]
# # Using libraries and modules
#
# ## Loading data
#
# ## pandas details
#
# dt.strftime(“%-m/%-d/%y, %H:%M”)
#
# ## numpy
#
# gives math.pi
#
# import numpy as np
#
# date and time
#
# statistics
#
# scipy.stats
#
# random
#
# decimal
#
# json
#
# csv
#
# sqlite3
#
# pickle
#
# datetime
#
# time
#
# unittest
#
# os
#
# sys
#
# try except
