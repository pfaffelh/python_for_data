# %% [markdown]
# # Some useful libraries/packages/modules
#
# [Download notebook](notebooks/05_libraries.ipynb).
#
# In this chapter, we take a little break. Although there are lots of
# things to learn, the material covered here has the role of helping to
# learn about the Python3 ecosystem and what is possible, rather than
# learn the details of various labraries. The first section, however, is
# central and will be needed in any Python3 project you will start.
#
# ## Loading modules (`import`)
#
# As in all programming languages, not all python programs come in a
# single file. If a Python3 project spans multiple files, an `import`
# becomes necessary. In Python3, there is syntax for `import`s as follows:
#
# | Syntax                    | Meaning            |
# |---------------------------|--------------------|
# | `import module`           | full module        |
# | `import module as name`   | alias              |
# | `from module import x`    | specific objects   |
# | `from module import *`    | everything (avoid) |
# | `import module.submodule` | submodule          |
#
# Generally, there are packages (folders), modules (a `.py`-file within a
# package, or a single `py`-file), and submodules. Every submodule is a
# module. In any case, the import loads the (sub-)module, and executes all
# top-level code inside it (i.e. everything which is not inside a
# function).
#
# There are three cases:
#
# 1.  You wrote some code in file `one.py` (e.g. some functions) which you
#     want to use in file `two.py`. (Note, btw, that the first digit in
#     `one.py` must be a letter.) Assume `one.py` is as follows:
#
# <!-- -->
#
#     # File: one.py
#
#     def myConst():
#         return 42
#
# Then, the import in `two.py` is either `import one` (both files must be
# in the same folder), or `from one import myConst` or (not recommended)
# `from one import *`. In the first case, you must prefix `myconst()` by
# `one`:
#
#     # File: two.py
#
#     import one
#     print(f"My constant is {one.myConst()}.")
#
# In the second case, there is no prefix:
#
#     from one import myConst
#     # or
#     from one import *
#     print(f"My constant is {myConst()}.")
#
# Observe that the latter option comes with the disadvantage that you
# cannot see from the call of `myconst()`, if it is defined in `two.py` or
# in`one.py`, so it becomes harder to keep track of your code if things
# become more complicated.
#
# If you have a folder `myPackage`, which holds `one.py`, you can must
# write `import myPackage`, `import myPackage.one` or
# `import myPackage.one as myNameOne` with differing ways to use
# `myConst()`:
#
#     import myPackage
#     print(f"My constant is {myPackage.one.myConst()}.")
#
#     import myPackage.one
#     print(f"My constant is {one.myConst()}.")
#
#     import myPackage.one as myName
#     print(f"My constant is {myName.myConst()}.")
#
# 1.  You want to use functions from a built-in library. Then, a simple
#     `import module` is often the best choice. We will see examples in
#     <a href="#sec-math" class="quarto-xref">Section 2</a>.
#
# 2.  You want to use functions from a library, which needs to be
#     installed. Here, before the `import module` even works, you need to
#     install the module in your python environment. In a terminal, within
#     your Python3 environment, use

# %%
# Uncomment the next line and run the cell for installation.
# This only needs to be done once for every package.
# If pip3 does not work, use pip instead. 
# !pip3 install numpy

# %% [markdown]
# and then, `import numpy` will work. We will see examples for this
# e.g. in **?@sec-loading**.
#
# ## Mathematics (`math`)
#
# The mathematical library in Python is used by `import math`. Then, you
# have e.g. the following functions, which are self-explanatory:
# `math.sqrt()`, `math.exp()`, `math.log()`, `math.sin()`, `math.cos()`,
# and constants like `math.pi` and `math.e`.
#
# ## Dates and times of day (`datetime`)
#
# In data science, we often have to handle dates. Their disadvantage is
# that there is no standard way to write these as strings. In Python3,
# this and various other problems around dates and times is solved by the
# `datetime`-library.
#
# Submodules (in fact, these are `class`es in this case) of this package
# are
#
# - `date`: handling dates
# - `time`: handling times
# - `datetime.datetime`: handling `datetimes`, i.e. dates and times
#   together
# - `timedelta`: time differences
# - `tzinfo` and `timezone`: handling timezones
#
# We will here use

# %%
import datetime

# %% [markdown]
# at the cost that `datetime`-objects are only accessible by saying
# `datetime.datetime` (the first `datetime` being the
# package`, the second`datetime\` being the class/submodule).
#
# Let us create a `datetime`-object\`:

# %%
dt = datetime.datetime(2026, 4, 21, 12, 15)
print(dt)
print(f"year: {dt.year}")
print(f"month: {dt.month}")
print(f"day: {dt.day}")
print(f"hour: {dt.hour}")
print(f"minutes: {dt.minute}")
print(f"second: {dt.second}")
print(f"microsecond: {dt.microsecond}")
print(f"date: {dt.date()}")
print(f"time: {dt.time()}")
# Out:
# 2026-04-21 12:15:00
# year: 2026
# month: 4
# day: 21
# hour: 12
# minutes: 15
# second: 0
# microsecond: 0
# date: 2026-04-21
# time: 12:15:00

# %% [markdown]
# which is the starting time of the first session in this course. As we
# see here, we can extract year,…, microseconds from the
# `datetime`-object.
#
# Often, we are given strings such as `"21.4.26, 12:15"`, and want to
# convert this into a `datetime` object. For this, we have
# `datetime.datetime.strptime`:

# %%
s = "21.4.26, 12:15"
dt = datetime.datetime.strptime(s, "%y.%m.%d, %H:%M")
print(s + f" is converted to {dt}.")
# Out:
# 21.4.26, 12:15 is converted to 2021-04-26 12:15:00.

# %% [markdown]
# (For the correct way to place %, y, m, d etc., it is in fact best to
# consult your favourite AI.)
#
# Reversely, we want to print a `datetime`-object in a certain way. For
# this, we have `datetime.datetime.strftime`:

# %%
print(dt.strftime("%-m/%-d/%y, %H:%M"))
# Out:
# 4/26/21, 12:15

# %% [markdown]
# which is the US-style output.
#
# Next, assume we want to compute the same time 12 weeks from now. For
# this, we use `datetime.timedelta`.

# %%
print(dt + datetime.timedelta(days=84))
# Out:
# 2021-07-19 12:15:00

# %% [markdown]
# Here are some more remarks:
#
# - `datetime.date` is not used very often. The reason is that you can
#   recover a `date` from a `datetime`, but not the other way round.
# - `datetime.time` has the same limitations.
# - We will not cover time-zones here, but if you have global data, they
#   will become important!
#
# ## Decimal numbers (`decimal`)
#
# We already saw that:

# %%
print(f"Rounding error: 0.2 + 0.1 = {0.2 + 0.1}.")
# Out:
# Rounding error: 0.2 + 0.1 = 0.30000000000000004.

# %% [markdown]
# The reason is that computers in general use a base of 2 for all
# computations, and 0.3 has a bad representation in this system. While
# this small error is acceptable often, it is not in some contexts (above
# all, finance). In this case, we can use the `decimal` library. Within
# `decimal`, a base of 10 is used, but calculations are slower than for
# `float`s.

# %%
from decimal import Decimal
print(f"Exact calculation: 0.2 + 0.1 = {Decimal('0.2') + Decimal('0.1')}.")
# Out:
# Exact calculation: 0.2 + 0.1 = 0.3.

# %% [markdown]
# ## Regular expressions (`re`)
#
# Sometimes, you need to find patterns in a string. In data science, this
# happens if some field contains unstructured text, and you want to
# extract information. As an example, assume you load data from a
# csv-file, and one columns contains all email-adresses of the
# corresponding item. If you read this, you have something like
# `"muller@gmail.com; muller@yahoo.com"`. However, you want to separate
# the two addresses, and store them in a `list`. One way to approach this
# is using a regular expression (which in this case reads
# `"\S+@\S+\.\S+"`):

# %%
import re

text = "muller@gmail.com; muller@yahoo.com"

emails = re.findall(r"\S+@\S+\.\S+", text)
print(emails)
# Out:
# ['muller@gmail.com;', 'muller@yahoo.com']

# %% [markdown]
# Let us quickly break this down to some extent, looking at
# `"\S+@\S+\.\S+"`: \* `\S`: any non-whitespace character \* `+`: one or
# more of the previous thing \* `@`: exactly the `@` symbol \* `\.`:
# exactly the dot `.` character (separating e.g. gmail from com)
#
# We can agree that this exactly what an email address looks like. The
# `re.finall()` finds all places in `text` which match this pattern and
# extracts them, putting them into a list. Note that there are more
# patterns to find than `\S`, `+` and exact matches. For this reason, it
# is advised to use AI when it comes to regular expressions.
#
# ## Storing and restoring objects (`pickle`)
#
# Sometimes, you want to store intermediate objects. One way is to write
# them out in files, but you can also use the `pickle`-library in order to
# write Python3 objects to disc. Here is an example:

# %%
import pickle

data = {"name": "Alice", "age": 30}

# Save to file (pickle)
with open("data.pkl", "wb") as f:
    pickle.dump(data, f)

# Load from file (unpickle)
with open("data.pkl", "rb") as f:
    loaded_data = pickle.load(f)

print(loaded_data)
# Out:
# {'name': 'Alice', 'age': 30}

# %% [markdown]
# ## Testing code (`pytest`)

# %%
# Uncomment the next line and run the cell for installation.
# If pip3 does not work, use pip instead. 
# !pip3 install pytest

# %% [markdown]
# When starting to code, producing reliable programs is both important and
# difficult. One – not the best – way to approach this is to rely on the
# program until something breaks. It is actually better to *test* the
# code, i.e. to write tests. This means that you tell your program that
# you expect a certain behavior.
#
# A simple and powerful library for this is `pytest`. When working with
# `.py`-files, you usually separate such tests in a separate file. Every
# test-case is within a function with name starting with `test_`. In a
# terminal, you can run `pytest` on that file, which performs all tests,
# and reports any error.
#
# However, we are working with Jupyter notebooks here, so we cannot run
# `pytest` on separate files. Although there are workarounds (the package
# `ipytest`), we will only go through some basics here, without importing
# `pytest`. This means we are introducing `assert`.

# %%
x = 5
y = -1
assert 2 + 2 = 4
assert 2 + 2 = 5

# %% [markdown]
# ## Using the operating system (`os`)
#
# For the kind of projects we envision, we often must access files, which
# happens via the operating system. We might also want to see all files in
# some directory, access them one by one, etc. Here, `folder` is the
# string of the name of a folder, and `file` is the string for the name of
# a file. \* `os.getcwd()`: returns the current working directory. \*
# `os.chdir(folder)`: this is a Python3 command for `cd`. \*
# `os.path.join(folder", file)`: gives a complete path from the folder and
# file name. \* `os.listdir(folder)`: returns a list of files within the
# folder. \* `os.path.exists(file)`: returns true or false if the file
# exists or not. \* `os.walk(folder)`: gives the triple
# `(root, dirs, files)`, where `root` is the absolute path of the folder,
# `dirs` are all direct subfolders in that folder, and `files` are the
# files in that folder. If folder has subfolders, it returns a list of
# triples for all subfolders.

# %%
import os
# Print all ipynb-files in the current folder
for file in os.listdir("."):
    if file.endswith(".ipynb"):
        print(file)
# Out:
# 04_container_data_types.ipynb
# 07_handling_data.ipynb
# 08_analyzing_data.ipynb
# 07_numpy_from_chatgpt.ipynb
# 09_example_project.ipynb
# 02_simple_data_types.ipynb
# 03_loops_and_conditions.ipynb
# 05_libraries.ipynb
# 07_handling_data copy.ipynb
# 10_misc.ipynb
# 11_numpy_from_chatgpt.ipynb
# index.ipynb
# 06_numerics.ipynb

# %%
# Print all folders and files in the parent folder
for root, dirs, files in os.walk(".."):
    print("ROOT:", root)
    print("DIRS:", dirs)
    print("FILES:", files)
# Out:
# ROOT: ..
# DIRS: ['myFiles', 'docs', 'latex', 'notebooks', 'venv', '.quarto', '.git']
# FILES: ['11_numpy_from_chatgpt.qmd', 'README.md', '10_misc.quarto_ipynb', '05_libraries.qmd', '09_example_project.qmd', 'index.quarto_ipynb', '06_numerics.quarto_ipynb', '.gitignore', '07_handling_data.qmd', '06_numerics.qmd', '02_simple_data_types.qmd', '08_analyzing_data.quarto_ipynb', '08_analyzing_data.qmd', '05_libraries.quarto_ipynb', '09_example_project.quarto_ipynb', '_quarto.yml', '02_simple_data_types.quarto_ipynb', '04_container_data_types.qmd', '07_handling_data.quarto_ipynb', 'requirements.txt', '03_loops_and_conditions.qmd', 'render_notebooks.sh', '10_misc.qmd', '04_container_data_types.quarto_ipynb', 'hello.txt', '11_numpy_from_chatgpt.quarto_ipynb', 'data.pkl', 'index.qmd', '03_loops_and_conditions.quarto_ipynb']
# ROOT: ../myFiles
# DIRS: []
# FILES: ['test.qmd', '01.ipynb']
# ROOT: ../docs
# DIRS: ['notebooks', 'site_libs', '11_numpy_from_chatgpt_files']
# FILES: ['11_numpy_from_chatgpt.html', '06_numerics.html', '08_analyzing_data.html', '05_libraries.html', 'index.html', 'search.json', 'python_for_data.pdf', '02_simple_data_types.html', '10_misc.html', '04_container_data_types.html', '03_loops_and_conditions.html', '07_handling_data.html', '09_example_project.html']
# ROOT: ../docs/notebooks
# DIRS: []
# FILES: ['04_container_data_types.ipynb', '07_handling_data.ipynb', '08_analyzing_data.ipynb', '07_numpy_from_chatgpt.ipynb', '09_example_project.ipynb', '02_simple_data_types.ipynb', '03_loops_and_conditions.ipynb', '05_libraries.ipynb', '07_handling_data copy.ipynb', '10_misc.ipynb', '11_numpy_from_chatgpt.ipynb', 'index.ipynb', '06_numerics.ipynb']
# ROOT: ../docs/site_libs
# DIRS: ['clipboard', 'quarto-nav', 'bootstrap', 'quarto-html', 'quarto-search']
# FILES: []
# ROOT: ../docs/site_libs/clipboard
# DIRS: []
# FILES: ['clipboard.min.js']
# ROOT: ../docs/site_libs/quarto-nav
# DIRS: []
# FILES: ['quarto-nav.js', 'headroom.min.js']
# ROOT: ../docs/site_libs/bootstrap
# DIRS: []
# FILES: ['bootstrap-d9e348642eb9c67787243e04f1ba7482.min.css', 'bootstrap-icons.woff', 'bootstrap-352f0346a3070dd3b7340e73962f3721.min.css', 'bootstrap-icons.css', 'bootstrap.min.js']
# ROOT: ../docs/site_libs/quarto-html
# DIRS: ['tabsets']
# FILES: ['tippy.umd.min.js', 'popper.min.js', 'anchor.min.js', 'quarto.js', 'quarto-syntax-highlighting-7c69b197886ae2a34062761d21e44731.css', 'tippy.css']
# ROOT: ../docs/site_libs/quarto-html/tabsets
# DIRS: []
# FILES: ['tabsets.js']
# ROOT: ../docs/site_libs/quarto-search
# DIRS: []
# FILES: ['fuse.min.js', 'autocomplete.umd.js', 'quarto-search.js']
# ROOT: ../docs/11_numpy_from_chatgpt_files
# DIRS: ['figure-html']
# FILES: []
# ROOT: ../docs/11_numpy_from_chatgpt_files/figure-html
# DIRS: []
# FILES: ['cell-64-output-1.png', 'cell-87-output-1.png', 'cell-39-output-1.png', 'cell-92-output-1.png', 'cell-71-output-1.png', 'cell-80-output-1.png', 'cell-59-output-1.png', 'cell-65-output-1.png', 'cell-63-output-2.png', 'cell-54-output-1.png', 'cell-126-output-1.png', 'cell-69-output-1.png', 'cell-57-output-2.png', 'cell-129-output-1.png', 'cell-128-output-1.png', 'cell-78-output-2.png', 'cell-85-output-1.png', 'cell-38-output-1.png', 'cell-61-output-1.png', 'cell-73-output-2.png', 'cell-49-output-1.png']
# ROOT: ../latex
# DIRS: []
# FILES: ['gcd.aux', 'gcd.log', 'gcd.pdf', 'gcd.tex']
# ROOT: ../notebooks
# DIRS: []
# FILES: ['11_numpy_from_chatgpt.qmd', '04_container_data_types.ipynb', '07_handling_data.ipynb', '05_libraries.qmd', '08_analyzing_data.ipynb', '07_numpy_from_chatgpt.ipynb', '09_example_project.qmd', '07_handling_data.qmd', '06_numerics.qmd', '02_simple_data_types.qmd', '08_analyzing_data.qmd', '05_libraries.quarto_ipynb', '09_example_project.ipynb', '02_simple_data_types.ipynb', '04_container_data_types.qmd', '03_loops_and_conditions.qmd', '10_misc.qmd', 'hello.txt', '03_loops_and_conditions.ipynb', '05_libraries.ipynb', 'data.pkl', '07_handling_data copy.ipynb', '10_misc.ipynb', 'index.qmd', '11_numpy_from_chatgpt.ipynb', 'index.ipynb', '06_numerics.ipynb']
# ROOT: ../venv
# DIRS: ['lib64', 'lib', 'share', 'etc', 'include', 'bin']
# FILES: ['pyvenv.cfg', '.gitignore']
# ROOT: ../venv/lib
# DIRS: ['python3.13']
# FILES: []
# ROOT: ../venv/lib/python3.13
# DIRS: ['site-packages']
# FILES: []
# ROOT: ../venv/lib/python3.13/site-packages
# DIRS: ['notebook-7.5.4.dist-info', 'pygments', 'httpx-0.28.1.dist-info', 'ipykernel', 'jupyter_server-2.17.0.dist-info', 'matplotlib', 'pyyaml-6.0.3.dist-info', 'jsonschema-4.26.0.dist-info', 'pyzmq.libs', 'json5-0.13.0.dist-info', 'defusedxml-0.7.1.dist-info', 'cffi-2.0.0.dist-info', 'jsonschema_specifications', 'numpy-2.4.1.dist-info', 'pexpect', 'jupyter_console-6.6.3.dist-info', 'pandocfilters-1.5.1.dist-info', 'prompt_toolkit', 'parso-0.8.6.dist-info', 'rfc3986_validator-0.1.1.dist-info', 'bleach', 'jupyter_server_terminals-0.5.4.dist-info', 
8.0.dist-info', 'ipykernel-7.2.0.dist-info', 'babel', 'argon2_cffi-25.1.0.dist-info', 'numpy.libs', 'jedi', 'ipython-9.11.0.dist-info', 'websocket_client-1.9.0.dist-info', 'asttokens-3.0.1.dist-info', '_distutils_hack', 'tzdata-2025.3.dist-info', 'httpcore-1.0.9.dist-info', '_yaml', 'pyparsing-3.3.2.dist-info', 'tzdata', 'argon2_cffi_bindings-25.1.0.dist-info', 'prometheus_client', 'traitlets-5.14.3.dist-info', 'jupyterlab_pygments', 'packaging-26.0.dist-info', 'rfc3339_validator-0.1.4.dist-info', 'pycparser-3.0.dist-info', 'rfc3987_syntax', 'jsonschema_specifications-2025.9.1.dist-info', 'jupyter_lsp', 'wcwidth-0.6.0.dist-info', 'kiwisolver', 'jupyter_lsp-2.3.0.dist-info', 'arrow', 'requests', 'httpcore', 'pandas', 'parso', 'jedi-0.19.2.dist-info', 'webcolors-25.10.0.dist-info', 'async_lru-2.2.0.dist-info', 'executing', 'webcolors', 'json5', 'terminado', 'pyzmq-27.1.0.dist-info', 'jupyte ...
# FILES: ['81d243bd2c585b0f4821__mypyc.cpython-313-x86_64-linux-gnu.so', 'rfc3986_validator.py', 'ipykernel_launcher.py', 'ipython_pygments_lexers.py', 'rfc3339_validator.py', 'jupyter.py', 'typing_extensions.py', 'nest_asyncio.py', 'pandocfilters.py', 'distutils-precedence.pth', 'jsonpointer.py', '_cffi_backend.cpython-313-x86_64-linux-gnu.so', 'decorator.py', 'six.py', 'pylab.py']
# ROOT: ../venv/lib/python3.13/site-packages/notebook-7.5.4.dist-info
# DIRS: ['licenses']
# FILES: ['WHEEL', 'METADATA', 'entry_points.txt', 'INSTALLER', 'RECORD']
# ROOT: ../venv/lib/python3.13/site-packages/notebook-7.5.4.dist-info/licenses
# DIRS: []
# FILES: ['LICENSE']
# ROOT: ../venv/lib/python3.13/site-packages/pygments
# DIRS: ['lexers', 'formatters', '__pycache__', 'filters', 'styles']
# FILES: ['regexopt.py', 'lexer.py', 'token.py', '__init__.py', 'unistring.py', '__main__.py', 'cmdline.py', 'sphinxext.py', 'util.py', 'formatter.py', 'scanner.py', 'filter.py', 'plugin.py', 'modeline.py', 'style.py', 'console.py']
# ROOT: ../venv/lib/python3.13/site-packages/pygments/lexers
# DIRS: ['__pycache__']
# FILES: ['hdl.py', '_sql_builtins.py', 'agile.py', 'sas.py', 'text.py', 'fift.py', 'ml.py', 'inferno.py', 'special.py', 'func.py', 'openscad.py', 'soong.py', 'sgf.py', 'gdscript.py', '_lilypond_builtins.py', 'kuin.py', 'maple.py', 'tlb.py', 'pointless.py', 'actionscript.py', 'graphql.py', '_julia_builtins.py', 'other.py', 'scdoc.py', 'nit.py', 'phix.py', 'elm.py', 'rust.py', 'devicetree.py', 'chapel.py', '_tsql_builtins.py', 'r.py', 'igor.py', 'ada.py', 'cddl.py', 'ldap.py', 'procfile.py', 'ecl.py', 'dylan.py', 'templates.py', '_scilab_builtins.py', 'diff.py', 'rego.py', '_lua_builtins.py', 'boa.py', 'math.py', 'tal.py', 'ncl.py', 'gleam.py', 'dsls.py', '_cl_builtins.py', 'julia.py', '
cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/httpx-0.28.1.dist-info
# DIRS: ['licenses']
# FILES: ['WHEEL', 'METADATA', 'entry_points.txt', 'INSTALLER', 'RECORD']
# ROOT: ../venv/lib/python3.13/site-packages/httpx-0.28.1.dist-info/licenses
# DIRS: []
# FILES: ['LICENSE.md']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel
# DIRS: ['comm', '__pycache__', 'pylab', 'gui', 'resources', 'inprocess']
# FILES: ['debugger.py', 'log.py', 'subshell.py', 'connect.py', '_version.py', 'embed.py', 'utils.py', '__init__.py', 'py.typed', 'jsonutil.py', 'socket_pair.py', 'control.py', 'shellchannel.py', 'ipkernel.py', 'subshell_manager.py', '__main__.py', 'thread.py', 'heartbeat.py', 'zmqshell.py', 'compiler.py', 'kernelbase.py', 'eventloops.py', 'parentpoller.py', 'kernelspec.py', 'displayhook.py', 'iostream.py', 'trio_runner.py', '_eventloop_macos.py', 'kernelapp.py']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/comm
# DIRS: ['__pycache__']
# FILES: ['manager.py', '__init__.py', 'comm.py']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/comm/__pycache__
# DIRS: []
# FILES: ['comm.cpython-313.pyc', 'manager.cpython-313.pyc', '__init__.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/__pycache__
# DIRS: []
# FILES: ['displayhook.cpython-313.pyc', 'zmqshell.cpython-313.pyc', 'trio_runner.cpython-313.pyc', '_eventloop_macos.cpython-313.pyc', 'log.cpython-313.pyc', 'debugger.cpython-313.pyc', 'socket_pair.cpython-313.pyc', 'iostream.cpython-313.pyc', 'utils.cpython-313.pyc', 'embed.cpython-313.pyc', 'parentpoller.cpython-313.pyc', '_version.cpython-313.pyc', 'jsonutil.cpython-313.pyc', 'kernelapp.cpython-313.pyc', 'control.cpython-313.pyc', '__init__.cpython-313.pyc', 'kernelbase.cpython-313.pyc', 'compiler.cpython-313.pyc', 'connect.cpython-313.pyc', 'kernelspec.cpython-313.pyc', '__main__.cpython-313.pyc', 'heartbeat.cpython-313.pyc', 'ipkernel.cpython-313.pyc', 'thread.cpython-313.pyc', 'subshell_manager.cpython-313.pyc', 'subshell.cpython-313.pyc', 'eventloops.cpython-313.pyc', 'shellchannel.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/pylab
# DIRS: ['__pycache__']
# FILES: ['config.py', '__init__.py', 'backend_inline.py']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/pylab/__pycache__
# DIRS: []
# FILES: ['backend_inline.cpython-313.pyc', '__init__.cpython-313.pyc', 'config.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/gui
# DIRS: ['__pycache__']
# FILES: ['__init__.py', 'gtk3embed.py', 'gtkembed.py']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/gui/__pycache__
# DIRS: []
# FILES: ['__init__.cpython-313.pyc', 'gtkembed.cpython-313.pyc', 'gtk3embed.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/resources
# DIRS: []
# FILES: ['logo-32x32.png', 'logo-64x64.png', 'logo-svg.svg']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/inprocess
# DIRS: ['__pycache__']
# FILES: ['blocking.py', 'manager.py', 'channels.py', '__init__.py', 'ipkernel.py', 'constants.py', 'socket.py', 'client.py']
# ROOT: ../venv/lib/python3.13/site-packages/ipykernel/inprocess/__pycache__
# DIRS: []
# FILES: ['channels.cpython-313.pyc', 'socket.cpython-313.pyc', 'blocking.cpython-313.pyc', 'manager.cpython-313.pyc', '__init__.cpython-313.pyc', 'constants.cpython-313.pyc', 'client.cpython-313.pyc', 'ipkernel.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/jupyter_server-2.17.0.dist-info
# DIRS: ['licenses']
# FILES: ['WHEEL', 'METADATA', 'entry_points.txt', 'INSTALLER', 'RECORD']
# ROOT: ../venv/lib/python3.13/site-packages/jupyter_server-2.17.0.dist-info/licenses
# DIRS: []
# FILES: ['LICENSE']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib
# DIRS: ['projections', 'axes', 'tri', 'backends', '__pycache__', 'testing', '_api', 'style', 'mpl-data', 'tests', 'sphinxext']
# FILES: ['_animation_data.py', '_path.cpython-313-x86_64-linux-gnu.so', 'backend_managers.py', 'scale.pyi', 'text.py', '_afm.py', 'colorbar.py', 'spines.py', '_cm_listed.py', 'rcsetup.py', 'texmanager.pyi', '_version.py', 'textpath.pyi', 'animation.py', 'hatch.pyi', '_cm_bivar.py', 'lines.pyi', '__init__.pyi', 'gridspec.py', 'table.pyi', 'container.pyi', 'mlab.py', 'legend_handler.pyi', 'markers.pyi', 'legend.pyi', 'cbook.py', '_qhull.pyi', '__init__.py', 'texmanager.py', 'font_manager.pyi', '_c_internal_utils.cpython-313-x86_64-linux-gnu.so', 'path.pyi', 'cbook.pyi', 'py.typed', 'transforms.py', '_path.pyi', 'patches.pyi', 'offsetbox.py', '_color_data.pyi', 'inset.py', 'patheffects.pyi', '_tri.cpython-313-x86_64-linux-gnu.so', '_tight_layout.py', '_pylab_helpers.pyi', '_c_internal_utils.pyi', 'colors.py', 'widgets.py', 'category.py', 'ft2font.cpython-313-x86_64-linux-gnu.so', '_docstring.py', 'path.py', '_docstring.pyi', 'backend_tools.pyi', 'axis.py', '_fontconfig_pattern.py', 'units.py', '_mathtext_data.py', 'ticker.pyi', '_enums.pyi', 'sankey.pyi', 'figure.py', 'markers.py', 'quiver.pyi', 'mathtext.pyi', 'collections.pyi', 'streamplot.py', 'stackplot.pyi', 'scale.py', 'textpath.py', 'dviread.pyi', 'table.py', '_type1font.py', 'colorizer.py', 'legend.py', 'mlab.pyi', '_qhull.cpython-313-x86_64-linux-gnu.so', 'sankey.py', 'rcsetup.pyi', 'quiver.py', 'gridspec.pyi', 'colorizer.pyi', 'ticker.py', 'dviread.py', 'patheffects.py', '_tight_bbox.py', 'text.pyi', '_color_data.py', 'backend_tools.py', 'mathtext.py', 'axis.pyi', '_internal_utils.py', '_enums.py', 'lines.py', '_mathtext.py', 'pyplot.py', 'collections.py', '_image.pyi', 'colors.pyi', 'animation.pyi', 'patches.py', 'backend_bases.pyi', 'image.py', 'artist.pyi', 'streamplot.pyi', 'transforms.pyi', 'contour.pyi', '_layoutgrid.py', 'legend_handler.py', 'dates.py', 'widgets.pyi', '_pylab_helpers.py', 'cm.py', '_cm.py', 'spines.pyi', 'artist.py', '_blocking_input.py', 'typing.py', 'offsetbox.pyi', '_tri.pyi', 'colorbar.pyi', '_cm_multivar.py', 'bezier.py', 'stackplot.py', 'font_manager.py', 'cm.pyi', 'hatch.py', 'pylab.py', 'inset.pyi', 'container.py', 'figure.pyi', 'layout_engine.pyi', 'bezier.pyi', 'image.pyi', 'contour.py', '_constrained_layout.py', 'layout_engine.py', 'backend_bases.py', '_image.cpython-313-x86_64-linux-gnu.so', 'backend_managers.pyi', 'ft2font.pyi', '_text_helpers.py']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/projections
# DIRS: ['__pycache__']
# FILES: ['__init__.pyi', '__init__.py', 'polar.pyi', 'geo.py', 'polar.py', 'geo.pyi']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/projections/__pycache__
# DIRS: []
# FILES: ['__init__.cpython-313.pyc', 'polar.cpython-313.pyc', 'geo.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/axes
# DIRS: ['__pycache__']
# FILES: ['__init__.pyi', '__init__.py', '_secondary_axes.pyi', '_axes.pyi', '_base.py', '_base.pyi', '_secondary_axes.py', '_axes.py']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/axes/__pycache__
# DIRS: []
# FILES: ['_axes.cpython-313.pyc', '_base.cpython-313.pyc', '__init__.cpython-313.pyc', '_secondary_axes.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/tri
# DIRS: ['__pycache__']
# FILES: ['_tripcolor.pyi', '_trifinder.py', '_triplot.py', '__init__.py', '_triinterpolate.py', '_tricontour.pyi', '_tripcolor.py', '_trifinder.pyi', '_tritools.pyi', '_tricontour.py', '_triinterpolate.pyi', '_trirefine.pyi', '_triangulation.pyi', '_triangulation.py', '_tritools.py', '_trirefine.py', '_triplot.pyi']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/tri/__pycache__
# DIRS: []
# FILES: ['_trirefine.cpython-313.pyc', '_tricontour.cpython-313.pyc', '_tripcolor.cpython-313.pyc', '_trifinder.cpython-313.pyc', '_triinterpolate.cpython-313.pyc', '_triangulation.cpython-313.pyc', '__init__.cpython-313.pyc', '_tritools.cpython-313.pyc', '_triplot.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/backends
# DIRS: ['web_backend', '__pycache__', 'qt_editor']
# FILES: ['backend_qtcairo.py', 'backend_qt5agg.py', 'registry.py', 'backend_wxcairo.py', 'backend_webagg.py', 'backend_tkcairo.py', 'backend_gtk4.py', 'backend_template.py', 'backend_mixed.py', 'backend_ps.py', '__init__.py', '_macosx.pyi', 'backend_webagg_core.py', '_tkagg.pyi', 'backend_agg.py', 'backend_nbagg.py', 'backend_gtk3.py', 'backend_qt5cairo.py', '_backend_pdf_ps.py', 'backend_qtagg.py', 'backend_tkagg.py', 'qt_compat.py', 'backend_wxagg.py', 'backend_gtk4agg.py', 'backend_wx.py', '_backend_tk.py', 'backend_gtk3agg.py', '_backend_agg.cpython-313-x86_64-linux-gnu.so', 'backend_gtk4cairo.py', 'backend_gtk3cairo.py', 'backend_cairo.py', 'backend_pdf.py', '_tkagg.cpython-313-x86_64-linux-gnu.so', 'backend_qt5.py', 'backend_pgf.py', 'backend_macosx.py', 'backend_qt.py', 'backend_svg.py', '_backend_gtk.py', '_backend_agg.pyi']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/backends/web_backend
# DIRS: ['js', 'css']
# FILES: ['all_figures.html', 'single_figure.html', 'ipython_inline_figure.html']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/backends/web_backend/js
# DIRS: []
# FILES: ['mpl_tornado.js', 'mpl.js', 'nbagg_mpl.js']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/backends/web_backend/css
# DIRS: []
# FILES: ['boilerplate.css', 'fbm.css', 'page.css', 'mpl.css']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/back
.cpython-313.pyc', '_type1font.cpython-313.pyc', 'pylab.cpython-313.pyc', '_color_data.cpython-313.pyc', 'path.cpython-313.pyc', 'dates.cpython-313.pyc', '_mathtext_data.cpython-313.pyc', '_cm_listed.cpython-313.pyc', 'font_manager.cpython-313.pyc', 'mlab.cpython-313.pyc', 'dviread.cpython-313.pyc', 'lines.cpython-313.pyc', 'textpath.cpython-313.pyc', 'legend.cpython-313.pyc', 'inset.cpython-313.pyc', 'quiver.cpython-313.pyc', 'offsetbox.cpython-313.pyc', 'contour.cpython-313.pyc', 'category.cpython-313.pyc', 'stackplot.cpython-313.pyc', '_afm.cpython-313.pyc', '_constrained_layout.cpython-313.pyc', '_cm.cpython-313.pyc', 'mathtext.cpython-313.pyc', '_text_helpers.cpython-313.pyc', 'rcsetup.cpython-313.pyc', 'widgets.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/testing
# DIRS: ['__pycache__', 'jpl_units']
# FILES: ['compare.pyi', '__init__.pyi', '__init__.py', 'compare.py', 'conftest.py', 'conftest.pyi', 'widgets.py', 'exceptions.py', '_markers.py', 'decorators.py', 'widgets.pyi', 'decorators.pyi']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/testing/__pycache__
# DIRS: []
# FILES: ['conftest.cpython-313.pyc', 'decorators.cpython-313.pyc', 'exceptions.cpython-313.pyc', '__init__.cpython-313.pyc', '_markers.cpython-313.pyc', 'widgets.cpython-313.pyc', 'compare.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/testing/jpl_units
# DIRS: ['__pycache__']
# FILES: ['Duration.py', '__init__.py', 'UnitDbl.py', 'UnitDblConverter.py', 'Epoch.py', 'UnitDblFormatter.py', 'StrConverter.py', 'EpochConverter.py']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/testing/jpl_units/__pycache__
# DIRS: []
# FILES: ['UnitDblFormatter.cpython-313.pyc', 'Epoch.cpython-313.pyc', 'UnitDblConverter.cpython-313.pyc', 'Duration.cpython-313.pyc', '__init__.cpython-313.pyc', 'StrConverter.cpython-313.pyc', 'UnitDbl.cpython-313.pyc', 'EpochConverter.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/_api
# DIRS: ['__pycache__']
# FILES: ['__init__.pyi', '__init__.py', 'deprecation.py', 'deprecation.pyi']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/_api/__pycache__
# DIRS: []
# FILES: ['deprecation.cpython-313.pyc', '__init__.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/style
# DIRS: ['__pycache__']
# FILES: ['__init__.py', 'core.py', 'core.pyi']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/style/__pycache__
# DIRS: []
# FILES: ['core.cpython-313.pyc', '__init__.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data
# DIRS: ['stylelib', 'plot_directive', 'images', 'sample_data', 'fonts']
# FILES: ['kpsewhich.lua', 'matplotlibrc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/stylelib
# DIRS: []
# FILES: ['seaborn-v0_8.mplstyle', 'tableau-colorblind10.mplstyle', 'grayscale.mplstyle', 'fivethirtyeight.mplstyle', 'dark_background.mplstyle', 'petroff10.mplstyle', 'Solarize_Light2.mplstyle', 'ggplot.mplstyle', 'bmh.mplstyle', '_classic_test_patch.mplstyle', 'seaborn-v0_8-paper.mplstyle', '_mpl-gallery.mplstyle', 'classic.mplstyle', 'seaborn-v0_8-muted.mplstyle', 'seaborn-v0_8-colorblind.mplstyle', 'seaborn-v0_8-deep.mplstyle', 'seaborn-v0_8-pastel.mplstyle', 'seaborn-v0_8-darkgrid.mplstyle', 'seaborn-v0_8-dark-palette.mplstyle', '_mpl-gallery-nogrid.mplstyle', 'seaborn-v0_8-bright.mplstyle', 'seaborn-v0_8-dark.mplstyle', 'seaborn-v0_8-ticks.mplstyle', 'seaborn-v0_8-poster.mplstyle', 'seaborn-v0_8-talk.mplstyle', 'seaborn-v0_8-notebook.mplstyle', 'seaborn-v0_8-white.mplstyle', 'fast.mplstyle', 'seaborn-v0_8-whitegrid.mplstyle']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/plot_directive
# DIRS: []
# FILES: ['plot_directive.css']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/images
# DIRS: []
# FILES: ['filesave-symbolic.svg', 'home.pdf', 'help.svg', 'subplots-symbolic.svg', 'filesave.pdf', 'zoom_to_rect.png', 'back.svg', 'qt4_editor_options.png', 'subplots.png', 'subplots.pdf', 'forward.pdf', 'qt4_editor_options_large.png', 'forward-symbolic.svg', 'back.png', 'qt4_editor_options.pdf', 'matplotlib.pdf', 'filesave.png', 'help_large.png', 'move.png', 'move.svg', 'qt4_editor_options.svg', 'filesave_large.png', 'help-symbolic.svg', 'matplotlib_large.png', 'forward.svg', 'home-symbolic.svg', 'home.svg', 'back-symbolic.svg', 'move.pdf', 'forward_large.png', 'subplots.svg', 'zoom_to_rect.svg', 'home.png', 'hand.pdf', 'back.pdf', 'matplotlib.png', 'home_large.png', 'matplotlib.svg', 'help.pdf', 'filesave.svg', 'help.png', 'subplots_large.png', 'back_large.png', 'zoom_to_rect.pdf', 'move-symbolic.svg', 'zoom_to_rect_large.png', 'move_large.png', 'hand.svg', 'hand.png', 'zoom_to_rect-symbolic.svg', 'forward.png']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/sample_data
# DIRS: ['axes_grid']
# FILES: ['Stocks.csv', 'topobathy.npz', 'README.txt', 'goog.npz', 'membrane.dat', 'grace_hopper.jpg', 'msft.csv', 's1045.ima.gz', 'embedding_in_wx3.xrc', 'Minduka_Present_Blue_Pack.png', 'logo2.png', 'eeg.dat', 'jacksboro_fault_dem.npz', 'data_x_x2_x3.csv']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/sample_data/axes_grid
# DIRS: []
# FILES: ['bivariate_normal.npy']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/fonts
# DIRS: ['afm', 'ttf', 'pdfcorefonts']
# FILES: []
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/fonts/afm
# DIRS: []
# FILES: ['pncb8a.afm', 'putb8a.afm', 'pbkli8a.afm', 'pbkd8a.afm', 'phvlo8a.afm', 'pagko8a.afm', 'phvb8an.afm', 'pzdr.afm', 'phvl8a.afm', 'putri8a.afm', 'pagd8a.afm', 'ptmbi8a.afm', 'pplb8a.afm', 'pplr8a.afm', 'cmmi10.afm', 'phvb8a.afm', 'pagdo8a.afm', 'pcrbo8a.afm', 'pcrro8a.afm', 'putr8a.afm', 'phvro8an.afm', 'pncr8a.afm', 'pbkdi8a.afm', 'pcrb8a.afm', 'putbi8a.afm', 'cmex10.afm', 'cmr10.afm', 'cmtt10.afm', 'pncbi8a.afm', 'pzcmi8a.afm', 'phvbo8a.afm', 'phvr8a.afm', 'psyr.afm', 'pplbi8a.afm', 'ptmb8a.afm', 'phvr8an.afm', 'pcrr8a.afm', 'ptmri8a.afm', 'pbkl8a.afm', 'ptmr8a.afm', 'pagk8a.afm', 'pplri8a.afm', 'phvbo8an.afm', 'pncri8a.afm', 'phvro8a.afm', 'cmsy10.afm']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/fonts/ttf
# DIRS: []
# FILES: ['DejaVuSerif.ttf', 'LICENSE_STIX', 'LICENSE_DEJAVU', 'STIXGeneralItalic.ttf', 'DejaVuSans-Oblique.ttf', 'STIXNonUniBol.ttf', 'STIXSizTwoSymBol.ttf', 'STIXSizOneSymBol.ttf', 'DejaVuSansMono-Oblique.ttf', 'DejaVuSansMono-Bold.ttf', 'STIXSizThreeSymReg.ttf', 'STIXGeneral.ttf', 'DejaVuSans.ttf', 'cmb10.ttf', 'cmmi10.ttf', 'cmex10.ttf', 'cmss10.ttf', 'STIXNonUniIta.ttf', 'DejaVuSerif-BoldItalic.ttf', 'STIXSizThreeSymBol.ttf', 'STIXSizTwoSymReg.ttf', 'DejaVuSansMono-BoldOblique.ttf', 'DejaVuSerifDisplay.ttf', 'STIXSizFourSymReg.ttf', 'STIXNonUniBolIta.ttf', 'DejaVuSansMono.ttf', 'STIXSizFourSymBol.ttf', 'STIXSizOneSymReg.ttf', 'cmtt10.ttf', 'DejaVuSans-BoldOblique.ttf', 'DejaVuSerif-Italic.ttf', 'STIXGeneralBolIta.ttf', 'STIXGeneralBol.ttf', 'cmsy10.ttf', 'DejaVuSerif-Bold.ttf', 'STIXSizFiveSymReg.ttf', 'STIXNonUni.ttf', 'cmr10.ttf', 'DejaVuSans-Bold.ttf', 'DejaVuSansDisplay.ttf']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts
# DIRS: []
# FILES: ['Courier-Oblique.afm', 'Courier.afm', 'Times-Bold.afm', 'Courier-BoldOblique.afm', 'Courier-Bold.afm', 'Times-BoldItalic.afm', 'Helvetica.afm', 'Helvetica-Bold.afm', 'Symbol.afm', 'readme.txt', 'Helvetica-BoldOblique.afm', 'Helvetica-Oblique.afm', 'Times-Italic.afm', 'Times-Roman.afm', 'ZapfDingbats.afm']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/tests
# DIRS: ['__pycache__']
# FILES: ['test_patheffects.py', 'test_api.py', 'test_axis.py', 'test_matplotlib.py', 'test_textpath.py', 'test_testing.py', 'test_fontconfig_pattern.py', 'test_rcparams.py', 'test_backend_template.py', 'test_streamplot.py', 'test_subplots.py', 'test_cycles.py', 'test_backend_inline.py', 'test_ticker.py', 'test_pickle.py', 'test_animation.py', 'test_datetime.py', 'test_bezier.py', 'test_backend_pgf.py', '__init__.py', 'test_units.py', 'test_table.py', 'test_scale.py', 'test_arrow_patches.py', 'test_colorbar.py', 'conftest.py', 'test_dviread.py', 'test_collections.py', 'test_backends_interactive.py', 'test_backend_tools.py', 'test_type1font.py', 'test_axes.py', 'test_mlab.py', 'test_bbox_tight.py', 'test_multivariate_colormaps.py', 'test_constrainedlayout.py', 'test_sankey.py', 'test_backend_gtk3.py', 'test_backend_pdf.py', 'test_widgets.py', 'test_backend_nbagg.py', 'test_afm.py', 'test_backend_qt.py', 'test_basic.py', 'test_legend.py', 'test_offsetbox.py', 'test_agg.py',
python-313.pyc', 'test_category.cpython-313.pyc', 'test_tightlayout.cpython-313.pyc', 'test_afm.cpython-313.pyc', '__init__.cpython-313.pyc', 'test_scale.cpython-313.pyc', 'test_lines.cpython-313.pyc', 'test_ticker.cpython-313.pyc', 'test_patheffects.cpython-313.pyc', 'test_path.cpython-313.pyc', 'test_backend_webagg.cpython-313.pyc', 'test_pickle.cpython-313.pyc', 'test_backend_qt.cpython-313.pyc', 'test_subplots.cpython-313.pyc', 'test_simplification.cpython-313.pyc', 'test_streamplot.cpython-313.pyc', 'test_skew.cpython-313.pyc', 'test_doc.cpython-313.pyc', 'test_fontconfig_pattern.cpython-313.pyc', 'test_texmanager.cpython-313.pyc', 'test_figure.cpython-313.pyc', 'test_backend_template.cpython-313.pyc', 'test_units.cpython-313.pyc', 'test_dviread.cpython-313.pyc', 'test_textpath.cpython-313.pyc', 'test_colors.cpython-313.pyc', 'test_bezier.cpython-313.pyc', 'test_arrow_patches.cpython-313.pyc', 'test_axes.cpython-313.pyc', 'test_font_manager.cpython-313.pyc', 'test_spines.cpython-313.pyc', 'test_backend_nbagg.cpython-313.pyc', 'test_type1font.cpython-313.pyc', 'test_ft2font.cpython-313.pyc', 'test_cycles.cpython-313.pyc', 'test_triangulation.cpython-313.pyc', 'test_api.cpython-313.pyc', 'test_backend_tk.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/sphinxext
# DIRS: ['__pycache__']
# FILES: ['roles.py', 'plot_directive.py', 'figmpl_directive.py', '__init__.py', 'mathmpl.py']
# ROOT: ../venv/lib/python3.13/site-packages/matplotlib/sphinxext/__pycache__
# DIRS: []
# FILES: ['roles.cpython-313.pyc', 'mathmpl.cpython-313.pyc', 'plot_directive.cpython-313.pyc', 'figmpl_directive.cpython-313.pyc', '__init__.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/pyyaml-6.0.3.dist-info
# DIRS: ['licenses']
# FILES: ['WHEEL', 'METADATA', 'INSTALLER', 'RECORD', 'top_level.txt']
# ROOT: ../venv/lib/python3.13/site-packages/pyyaml-6.0.3.dist-info/licenses
# DIRS: []
# FILES: ['LICENSE']
# ROOT: ../venv/lib/python3.13/site-packages/jsonschema-4.26.0.dist-info
# DIRS: ['licenses']
# FILES: ['WHEEL', 'METADATA', 'entry_points.txt', 'INSTALLER', 'RECORD']
# ROOT: ../venv/lib/python3.13/site-packages/jsonschema-4.26.0.dist-info/licenses
# DIRS: []
# FILES: ['COPYING']
# ROOT: ../venv/lib/python3.13/site-packages/pyzmq.libs
# DIRS: []
# FILES: ['libzmq-7b073b3d.so.5.2.5', 'libsodium-19479d6d.so.26.2.0']
# ROOT: ../venv/lib/python3.13/site-packages/json5-0.13.0.dist-info
# DIRS: ['licenses']
# FILES: ['WHEEL', 'METADATA', 'entry_points.txt', 'INSTALLER', 'RECORD', 'top_level.txt']
# ROOT: ../venv/lib/python3.13/site-packages/json5-0.13.0.dist-info/licenses
# DIRS: []
# FILES: ['LICENSE']
# ROOT: ../venv/lib/python3.13/site-packages/defusedxml-0.7.1.dist-info
# DIRS: []
# FILES: ['WHEEL', 'METADATA', 'INSTALLER', 'RECORD', 'top_level.txt', 'LICENSE']
# ROOT: ../venv/lib/python3.13/site-packages/cffi-2.0.0.dist-info
# DIRS: ['licenses']
# FILES: ['WHEEL', 'METADATA', 'entry_points.txt', 'INSTALLER', 'RECORD', 'top_level.txt']
# ROOT: ../venv/lib/python3.13/site-packages/cffi-2.0.0.dist-info/licenses
# DIRS: []
# FILES: ['AUTHORS', 'LICENSE']
# ROOT: ../venv/lib/python3.13/site-packages/jsonschema_specifications
# DIRS: ['__pycache__', 'schemas', 'tests']
# FILES: ['_core.py', '__init__.py']
# ROOT: ../venv/lib/python3.13/site-packages/jsonschema_specifications/__pycache__
# DIRS: []
# FILES: ['_core.cpython-313.pyc', '__init__.cpython-313.pyc']
# ROOT: ../venv/lib/python3.13/site-packages/jsonschema_specifications/schemas
# DIRS: ['draft6', 'draft7', 'draft202012', 'draft4', 'draft3', 'draft201909']
# FILES: []
# ROOT: ../venv/lib/python3.13/site-packages/jsonschema_specifications/schemas/draft6
# DIRS: []
# FILES: ['metaschema.json']
# ROOT: ../venv/lib/python3.13/site-packages/jsonschema_specifications/schemas/draft7
# DIRS: []
# FILES: ['metaschema.json']
# ROOT: ../venv/lib/python3.13/site-packages/jsonschema_specifications/schemas/draft202012
# ...
# ROOT: ../.git/objects/1b
# DIRS: []
# FILES: ['55a699d8cc45e8d0913fbd7f122155ffd49fd4']
# ROOT: ../.git/objects/82
# DIRS: []
# FILES: ['b40f57e13c36328902a8a9fa18d1239e7508d3', 'a2d9a3785f4fabc73a7ddbe9ccc1e9e22bbb66', '435d78e732820eb239854b47fe3f525fc37c3c', '62fae1126a912bf73b1c06c1b0dcf182e178ac']
# ROOT: ../.git/objects/9c
# DIRS: []
# FILES: ['6046d3e46e31ae6139dacdf455b9acae32ba35']
# ROOT: ../.git/objects/2d
# DIRS: []
# FILES: ['514008e27a1fe018abb683c394d51172722d16']
# ROOT: ../.git/objects/e4
# DIRS: []
# FILES: ['eb01fff1112df446914e26c2e3671963c1287e']
# ROOT: ../.git/objects/c3
# DIRS: []
# FILES: ['8231c8501484f5efee02d4f9fc0d0feaecfd27', '769e93daebb68e84e7abbbdcb047cd2b2a2621']
# ROOT: ../.git/objects/d8
# DIRS: []
# FILES: ['6c688b0e7b45f700d0e7486260864fb93c3704']
# ROOT: ../.git/objects/39
# DIRS: []
# FILES: ['89d242a86e5d39c2e143202c39a2ab2100aed9', '4b746bbc5db427c7e19c62aeae9d98510462cf']
# ROOT: ../.git/objects/66
# DIRS: []
# FILES: ['03b129b943be7df4dc3db21d1d7b15c4622260']
# ROOT: ../.git/objects/86
# DIRS: []
# FILES: ['43e8d1066731dd953dba13b1194729b0b7bfad', '8c2d0ac48f64eed099ace02fd2ad44aa0c7c59', '8fc2f76f5f809d22b792a731156609718efd2f']
# ROOT: ../.git/objects/5d
# DIRS: []
# FILES: ['47e25db456db2c926a21326d488d280158215b', '9330a257dd1ef3fb30344abb2f91217d9ea91f']
# ROOT: ../.git/objects/cc
# DIRS: []
# FILES: ['83523962ed68178449ba0643f9899572066125']
# ROOT: ../.git/objects/5e
# DIRS: []
# FILES: ['3757aabd9dcdf31ba738e3fcc2c14da0e57a17']
# ROOT: ../.git/objects/3e
# DIRS: []
# FILES: ['2d252c5c30a0ec865204c603ffb42f604974fe', 'dde89b843d2dd8bdef4e05c335bb3ed28148e1']
# ROOT: ../.git/objects/41
# DIRS: []
# FILES: ['961f54e86ceb3b64efba5f8561abec6e175dcc', '3f8aef2fb61660924da71d2701eed64d2be20c', '4b7bc81ff4f30c8696e92e4a490b81a716101e']
# ROOT: ../.git/objects/84
# DIRS: []
# FILES: ['4076c9b5d83e157b96abbe3579e8118d8d8a0e']
# ROOT: ../.git/objects/e7
# DIRS: []
# FILES: ['f20fb3669e1dd40bcc9e3bf9837434cd7d31dc']
# ROOT: ../.git/objects/4b
# DIRS: []
# FILES: ['8aeee4732809c9299287b1dd1ebf63ccfe3b08']
# ROOT: ../.git/objects/38
# DIRS: []
# FILES: ['cc43057bdfaae23727b4b638cf62a7594712c2', '869568b858717c973e5dd9693ef7e5d6e9d623']
# ROOT: ../.git/objects/10
# DIRS: []
# FILES: ['66ef404f079298fa681cdeb61280e4122e79af', '54558d9b19ae7cf56dc7d0c0f846ed0f2579da', '7a2aa3245553d42afd4ebab5add0590a5f8121', '8456ac511de8ba4acfaa4de723bb7d430ea054']
# ROOT: ../.git/objects/99
# DIRS: []
# FILES: ['8152fb5005de0146b480968d884573b828a7ab', '0350b292ca5812ead196ce8718c0846ed92371']
# ROOT: ../.git/objects/8a
# DIRS: []
# FILES: ['d1e2b947f7e6e9e3ffef79b7f2599c8c8c2b61', '98d668b9449fd3916d57005cd8446623e17cd8']
# ROOT: ../.git/objects/7e
# DIRS: []
# FILES: ['295ac41b418932b372ca54620fdf561e201148', '1dbf4a959c181b23ff080edcee8cf8c25d9ca4', '6642b97bf179f167a470cb4707c381beb5a802']
# ROOT: ../.git/objects/37
# DIRS: []
# FILES: ['1b4fea9baf92dfaa0386cfb56d855694a83c49', '623cf844a7eb728029e583087fcf32032871e4']
# ROOT: ../.git/objects/af
# DIRS: []
# FILES: ['ec0662e3a0a860f8e9cc78df4c498c13305029']
# ROOT: ../.git/objects/a6
# DIRS: []
# FILES: ['c9399c37d1737be6ecdd998eac38d7b4f7c78b', '1ea22a80baca950eca4e1d2d300d7233221184', 'ecb96c1900242a614cbf68ffbb789d9d740edb', 'd3e80a1661f1f7a89db17cb693fc1dc17c6de1']
# ROOT: ../.git/objects/c8
# DIRS: []
# FILES: ['462b37f376725a7379d5640a26a2aadbfbb32e', 'ac2d309f669a9c5a91beefb68574d7a3359f63']
# ROOT: ../.git/objects/e3
# DIRS: []
# FILES: ['726d728b717eb344760b3db47f7e9b142ed0fb']
# ROOT: ../.git/objects/75
# DIRS: []
# FILES: ['c870936b373a7295091306994d24de1835c133']
# ROOT: ../.git/objects/c4
# DIRS: []
# FILES: ['6a6c22e5e9a82abf7a55e2caf9e1ae7fdac42c']
# ROOT: ../.git/objects/56
# DIRS: []
# FILES: ['99876c08d33cd2b108873db03474a7dc5da0d3', '86f8b716ecc380166475cb31c0626a9377c015', '0d4ed88416ac8e4371e766daf702ff6fe2f34e']
# ROOT: ../.git/objects/71
# DIRS: []
# FILES: ['e4a21d3af19c576d84ae16ffdc9b95fee56ba6', 'c1709325dcc13f54bc6967ca36b3deb1f8b677', '3a71b472dc8b9d8c89f56beb0375b6e695c800']
# ROOT: ../.git/objects/52
# DIRS: []
# FILES: ['42b3ae120bea06d342984b6a1ebd513c463c7d', 'a4cea09a3abedbe4b3478b4fc6d5761344cd31', 'fefef243166cbe2043a86c0d0a41b9267f7ee8', 'ba70cff287db51d005a4c8aba5de2115372f48']
# ROOT: ../.git/objects/89
# DIRS: []
# FILES: ['fedf10a6af9f78df6652be10051e091bffdd72', '78393e55772e5ccbba53e7e192bd29ba081b04']
# ROOT: ../.git/objects/8e
# DIRS: []
# FILES: ['4f9fc1a0305a93c867aa2c65b87dbe19e90890']
# ROOT: ../.git/objects/ce
# DIRS: []
# FILES: ['8d95e7714767e1793b4407dbb1ac9231a27f34', 'fed2660438bf984a60450604499e364892f44d', '29385df7f246ed5d14af209fbfc38191b4537b']
# ROOT: ../.git/objects/68
# DIRS: []
# FILES: ['c983e84b952e0c619141a40bf8e2185bc5bf29']
# ROOT: ../.git/objects/62
# DIRS: []
# FILES: ['54f54be6c51b95dbde7328afba4efdbf950285', 'e57a6a6ff1bf73ca219248a6ca2c5da5bae884']
# ROOT: ../.git/objects/5f
# DIRS: []
# FILES: ['20eda3ab230ab4f60bc6ca5f69223019e0f244', 'db7c03d701d0a8ba9a0d53d6637973881a8b78', '0f4f5ff48c7ae81f37bf490beaade7f450fb51', '5e12101a455eb0c4672ef8505df6a24892a769']
# ROOT: ../.git/objects/33
# DIRS: []
# FILES: ['999d4dee14d8fe074c81886d5ecf7cd6ead7a2']
# ROOT: ../.git/objects/2f
# DIRS: []
# FILES: ['2754b47b8a3f2da3a1815b84b0ff196b931894', '19413961223e4ef118defb1b679c3644ee0cc3', '6f30a820a20be8b62c37fcd433d0de761411ab']
# ROOT: ../.git/objects/07
# DIRS: []
# FILES: ['a1731cbd4e4bd8b44dd2a5831869d0a11a80d0', 'bb5b8a691b7c9bafbcc5765ddfe58e26eed5dd', '1fae1d6eefc48f1929efa3ced12e7df4143752']
# ROOT: ../.git/objects/28
# DIRS: []
# FILES: ['ffa1d1e219c623aeab1a03f5b53e7765d21d14', '3886f1d61e2ca32e58a940b4d031d2ce4f593c']
# ROOT: ../.git/objects/b1
# DIRS: []
# FILES: ['3d702a51fc7d787ce20dd7feafd54c78a120ea', '6d8a93ff0c2cc1f3aced51a03f1dad6767061a']
# ROOT: ../.git/objects/eb
# DIRS: []
# FILES: ['bc8d733ee8fe488f0f04ec48d9c4d997a8e7c0']
# ROOT: ../.git/objects/35
# DIRS: []
# FILES: ['902fcfd3b0d6a12466ac5800b78b469fd1eca2', 'c716c8f8e42006698ea30d11406985a6266976', '4d7edc8ef3801df0fb3c83932ef10c2bf2e391']
# ROOT: ../.git/objects/5a
# DIRS: []
# FILES: ['c814d1e2bf288721fe5f4d9f0aae2a6283903e']
# ROOT: ../.git/objects/7c
# DIRS: []
# FILES: ['70d25ce527025aedce6be712e1754fd0ccfa29', 'e4327a9dbdb42c73f010eec4bc61968e7a68fa', 'fb4f3a5543d81c799270712cdf5ac114b94bc8', '0a36cdbadcbd96ef53072916f7ecb06ab56142']
# ROOT: ../.git/objects/c7
# DIRS: []
# FILES: ['d0268b97747e3f6e07a900d5c895f1b533bf17']
# ROOT: ../.git/objects/ad
# DIRS: []
# FILES: ['1c21a0e54622900de57adef724dba2a8a347ef', 'c28356e2f591038d4e691cb5b418d7a490bfb1', '46b5daaadfb9223f274cdb32b072a0143f1137', '9d9373ef3c766a02d4e3fa16ed6427b6712e36']
# ROOT: ../.git/objects/ed
# DIRS: []
# FILES: ['8e4c65b5353902dfed89f8faa58d9a2a04d1d7', 'e28fcd2d2474585b9a5aa2a181853e7177d36b']
# ROOT: ../.git/objects/09
# DIRS: []
# FILES: ['0cff8976f63caa84a99736e905e2a7189a3d32', '2e2c6db53da0ac68fdbb4cc2276f58daa4e3c8']
# ROOT: ../.git/objects/49
# DIRS: []
# FILES: ['6171819a27a6e7c0059cd9a9e514e7552005a0']
# ROOT: ../.git/objects/f7
# DIRS: []
# FILES: ['b44d331ff907e8d678d1b58c373db73a5185a6', 'd069c9f6e52b2e35da31c3e4957e910ad7f765', 'bd6f3e900a728e018da96a82126fbd6ca53682', '52027dee6d1aa86a146f1f335f9a60a0aa0fe4', '9b4812785d9ff8ff7d22031d488bab6102cce9', 'ae4e6033348d868dbc8cb17fa05ccbb89b30ac']
# ROOT: ../.git/objects/1f
# DIRS: []
# FILES: ['8a8743f12c77c93189e40c093786d7355a70b3', '4022c298a6a78b58297d8bab0d71965c5ac1b8']
# ROOT: ../.git/objects/d4
# DIRS: []
# FILES: ['74a931097bdf55ffcd2b00331b2b29dab7caca', '1b775e6ea7a5524b34caa969522d6c9bd01b09', '7df1d4797a7c6fd5f82ec0860285086920f297', '39a3ef48afe9e5f5bbdf908003a65386e22fd9']
# ROOT: ../.git/objects/17
# DIRS: []
# FILES: ['21e816bde266b42e7eaa008f1d436c73a879ba']
# ROOT: ../.git/objects/d3
# DIRS: []
# FILES: ['19a4eb98ccde77886afaeeb8bada2cc9bd5504', 'fd62b319d83c6f62fa2915bf5dea9ff4a3dcc4']
# ROOT: ../.git/objects/1e
# DIRS: []
# FILES: ['117df0c1d46d0bd75e044f8606208d4c2c9d58']
# ROOT: ../.git/objects/e6
# DIRS: []
# FILES: ['ae635cb1f82b176c18afa80dfa029c7a536e70', 'bff0022741fbadba7425e1c9a23ca0c55b55ef']
# ROOT: ../.git/objects/be
# DIRS: []
# FILES: ['9dfab44082bd67d5090080275acba7f5d50feb', '46ae3d54dd000cae18efccd8517e33850f5612', '201e2105a068092e6d3aadd0d10fcfb7eab2b9']
# ROOT: ../.git/objects/d5
# DIRS: []
# FILES: ['c216f811dc8b52481464265fdddb98dfe4bb86', 'd22279ea28259e322571e2b96a4940b97e4899', '6f117a9442a15314582498c82aebc455ae8beb', 'd9654e435f98042a691d074fe8b3a1621134ce', '242974e3a10754294526faa048c8087090d706', '694d5212300475921e165287bfeb3a927eef69', '367361820f257cf99f5f4bfd7d964cc11ade79']
# ROOT: ../.git/objects/16
# DIRS: []
# FILES: ['f774723d8cf6912af030598388c308e6ef4f07', '5a6df10008c5885f2f61a2fa93751c67c9fb78', 'c49c60828f8c4b4dc713b3a16b4b2ce654dd52']
# ROOT: ../.git/objects/48
# DIRS: []
# FILES: ['32d7e08abd1df1a810e5e08846c704bf8c119e', '464ced18b2a6895e068439c9442c0ed4383d86', 'f28c361dd90ed74cbc7ab3699f7bd1c0e2147f', '10a3f7732f89e155b2974ecc84b1426b64bdb0']
# ROOT: ../.git/objects/77
# DIRS: []
# FILES: ['a17872b0ffeb93af35c24a9a979d79bf2b81fe', 'b40e090b23476bff8fe2bb704da71ea95a6550']
# ROOT: ../.git/objects/54
# DIRS: []
# FILES: ['b5b989efa6599bd0fe06da06dc31438975aec8']
# ROOT: ../.git/objects/bb
# DIRS: []
# FILES: ['30fedf1d42222b30b899ab4a741d9699494777', '107296e0e99b9ef213ab785e2225c3ce83d419', 'f7487e18e7fe6ac6ac90a8cafd680b0edef50c', '7f47fad2dc7d02cb368a610f70be32e4e50ed4', 'd17f86ec2aa3f8de52f4292f4dff8af547443c']
# ROOT: ../.git/objects/76
# DIRS: []
# FILES: ['c8fa99326455df5a2df8ea9ad4b6e308723824', '4bbbcc5e7592d0ce3adc10e95a77d66d8c8e40']
# ROOT: ../.git/objects/15
# DIRS: []
# FILES: ['2ddd513a9371646958f1bf20bc631ba67d5dbd', 'fc0dbfd9777d60217ea2f1ccff5c80f523a52e', 'cd51d98d2b05329f464743bae9c660c7f4cdf1', '793580b9a47020dc57dae3e76f54769ad9f1bc']
# ROOT: ../.git/objects/7d
# DIRS: []
# FILES: ['7a8a2a27526a777c6d1ef839b3a32e71430582']
# ROOT: ../.git/objects/aa
# DIRS: []
# FILES: ['4b911cd9bc8b33a04ba96bac69b9669a8f318b', '627936fa558f5974448e3a23885b42b3c8adda', 'a8785df501c865f0b9abce1a0d0b5afcb1b8bc', '3b1e9fe7ebcda5a9de8360504c231b9b860780']
# ROOT: ../.git/objects/11
# DIRS: []
# FILES: ['03f811ed80f17985ecf61e0d50e3359484244f']
# ROOT: ../.git/objects/0d
# DIRS: []
# FILES: ['a1f03bd4cc235b196190c76f94b84f834fce86', 'f5ccbc1cc141c64d9a55bb289eb867e248c19f']
# ROOT: ../.git/objects/0c
# DIRS: []
# FILES: ['e7c6f71aca58a8e7894e5d2435418f97955a04']
# ROOT: ../.git/objects/87
# DIRS: []
# FILES: ['b68b996323850b166cff95f422528e36a693de', '9790cf2a1318e1cd970efb222cbb7ac5e5ef3d', 'b3a3a2bc5fa08e303e8e1187ed964da305195f']
# ROOT: ../.git/objects/bc
# DIRS: []
# FILES: ['4fee2b218a44a1a5dc0aad740ca533f1000e88', 'fc452ae9b95ebed351bcb5a898fa41d4e9a207', '5bb213d065881e6ad3dac60570d155f977ee16']
# ROOT: ../.git/objects/cf
# DIRS: []
# FILES: ['982dd4316e54ed1c57c49c1c0f26eb4fb97f75']
# ROOT: ../.git/objects/ca
# DIRS: []
# FILES: ['292be32b252f9a40e231f3a3e696b2506f7c96']
# ROOT: ../.git/objects/53
# DIRS: []
# FILES: ['567e9ab325a8d914211b2b1016e8ae80947373']
# ROOT: ../.git/objects/83
# DIRS: []
# FILES: ['f036cc81caf154a133a9dbd00632d58c94bb75']
# ROOT: ../.git/objects/6a
# DIRS: []
# FILES: ['78fe6897be0eb0c0fa632b653e2947074bafbc']
# ROOT: ../.git/objects/02
# DIRS: []
# FILES: ['e9900db80c588abebdd65d9fea4a10997e0138', '6703b9de28f1e8ebb65f7042c81d1a0dd01e97', 'e90e67105a64c73382f4d1cc3bb4a8f00b3022']
# ROOT: ../.git/objects/14
# DIRS: []
# FILES: ['4050ce295047203e0c493393b399d3af86755e', '847b8c9bba6acd59a2a5c21bdaccb7d70a9f8f']
# ROOT: ../.git/objects/dd
# DIRS: []
# FILES: ['671910ba593134a7110019f2769d76d8792872', '0d5a6ddbd48e35ad118bf40500363504c567a3']
# ROOT: ../.git/objects/72
# DIRS: []
# FILES: ['c6677151eece6ee5dcacd8268cbd9b7f4149a1', '0ea40bc495c3c5836923bc9a3c2ba3fceeb581']
# ROOT: ../.git/objects/21
# DIRS: []
# FILES: ['be7206264fefce9a34bc7725c693145bcaf9ec', 'e06ce45e888b28e348291decf24cbbbae5a5a4']
# ROOT: ../.git/objects/91
# DIRS: []
# FILES: ['b543bd1a2f59b703947626c437e031179a80ef']
# ROOT: ../.git/objects/05
# DIRS: []
# FILES: ['58f6496eab0d9d28fff3bdc3e254a9fc126ee2', '491e5fa5078d2bec4505a760c281dec70e5d81']
# ROOT: ../.git/objects/44
# DIRS: []
# FILES: ['c9c304ca382f0427b60cf2920e0d7437c116df']
# ROOT: ../.git/objects/50
# DIRS: []
# FILES: ['fd7ea5ff3057b4bbc41eec422581e76fc3c424', '6ec7f3d8496d3196d5a28d2e163c8b8f00869a', 'c5c7256cf8e43b6ead90671d33ac8d6bbe60a2', '05df9a7d54f71183cade4d6b35fb9069b5b190']
# ROOT: ../.git/objects/3d
# DIRS: []
# FILES: ['083b731470d6f0221146c9e8bed312f750a0f2', '9cd4b77cb35e45c467ca052bd1c952f6893789', 'b42b89ad47ccbe16d4a8b5d5b32d89e5e599b2']
# ROOT: ../.git/objects/ba
# DIRS: []
# FILES: ['a0059072800fa74dc3906058a92c614902f66e']
# ROOT: ../.git/objects/b6
# DIRS: []
# FILES: ['4012178f9cbc148dca209ceaf227aee4833711']
# ROOT: ../.git/objects/e2
# DIRS: []
# FILES: ['092ce979d4fd138350a3a4387d728eecd1db85', '801fac7d59a3dacf7c40e2f017211a030a8834', '1657fa3309ca805775c561965969ef2a7ab928', 'a2abd0e53d28dbc9d8ecf2382a3bfd5cb7d821']
# ROOT: ../.git/objects/0b
# DIRS: []
# FILES: ['be9f1971207e5d36331a128e9d41d430c23833', '39eb24f7091a7e67c1685b4ad921ddce43e6cf', 'c51054487b05972ac2afed77a4ae861c948ec7']
# ROOT: ../.git/objects/85
# DIRS: []
# FILES: ['d4cfb820fa2213dd7564897d7491365e7dd56f', '30b98270b5c2a70ffbac0bd7e7760d2b002b1d', '1b2b5aa8bdb8d3a51756671fef2ea57474ba3d']
# ROOT: ../.git/objects/63
# DIRS: []
# FILES: ['7265e089873d3858aca07a056fc0c484ac0119', 'e951dca0cc2373863468d764e6414e7b621f0f', '3c5ea4d12089cf4ea700bbe2f58cadf450577d', '1b39da51d600b742df5cf3ce5b7d4e40e5893b']
# ROOT: ../.git/objects/81
# DIRS: []
# FILES: ['d329bba56a82b78f1a7b529082149bea01fb6f', '7c6c962089e085ec18bad2c8f71d398bbe4230', '9b9c2a2c48304aafa91170ce07b87113b6486c']
# ROOT: ../.git/objects/fe
# DIRS: []
# FILES: ['174bb9be802681ab511aefa067544de9ac73bc', '0c6cf88aa4770aa317369bf1faafd278ac377f']
# ROOT: ../.git/objects/36
# DIRS: []
# FILES: ['c285fedab1912f378f1ad9704f3cc751a73c84']
# ROOT: ../.git/objects/5b
# DIRS: []
# FILES: ['e646a335b7fad203fe7a960dd30477d33c25e7']
# ROOT: ../.git/objects/69
# DIRS: []
# FILES: ['0317ecd195398a91f76376309c12195cb55d9f']
# ROOT: ../.git/objects/bd
# DIRS: []
# FILES: ['bb3a23495cdfff586144262e52f9e59d1eb2cb', '972b92975e1f95a5c75f35367e9a229e8e1b82', '497840c7cbb99a6e2e935544f53b183a01d4a6']
# ROOT: ../.git/objects/d1
# DIRS: []
# FILES: ['49f0889678337600f34aedb604a9df9b2d8897', 'cd392db52f777050a5b042e8ed70973757df3c']
# ROOT: ../.git/objects/cb
# DIRS: []
# FILES: ['c101efa47128873afd2e58a8f2a1e37556cbac']
# ROOT: ../.git/objects/a2
# DIRS: []
# FILES: ['07af58a88d78437da49fc4b2817f802f86b075', '8daa8300c539606adabe41e0011dbc56da8ab1']
# ROOT: ../.git/objects/24
# DIRS: []
# FILES: ['631161d50e9f9aa0cd4599ebc3819295399348', 'a0f16b34ad67996cfd2edbafb3ca67860f88dd']
# ROOT: ../.git/objects/7f
# DIRS: []
# FILES: ['c9f567403c5156956712cb24f2c11064fe679f', '6eeaa2156fa6dfb96c9c7e72f00e0a3c8caaa9', 'cc30aeb68161070ffbc736abd9b6c840e8f022']
# ROOT: ../.git/objects/65
# DIRS: []
# FILES: ['50555c260caadc68434d017f0acd4e8ad145ff']
# ROOT: ../.git/objects/58
# DIRS: []
# FILES: ['61071debfe9b11e510c406ec1041b9e31ef846', '71f76732f34cdd72064c3f1b61d8cef224b958', '179af76b07d06f1fa094949ff18b1b4bbdca90', 'dd6a5dc8b0d4f2476b646e731483e8d1b3c126']
# ROOT: ../.git/objects/3f
# DIRS: []
# FILES: ['6689d89f53a9687a39208a2fdd2a675f057cff']
# ROOT: ../.git/objects/98
# DIRS: []
# FILES: ['1d63a140d8aaac6ac67faab9d5c8cdbd38f744']
# ROOT: ../.git/objects/67
# DIRS: []
# FILES: ['5bfe9386bd8bb155958911fb71b52cb32daa98']
# ROOT: ../.git/objects/4f
# DIRS: []
# FILES: ['6f4869762a21a8d41d24779b2f3be5df566e0f']
# ROOT: ../.git/objects/e0
# DIRS: []
# FILES: ['0996cbcf6dd496d84d528a58e7566cf2a16aa0', '2f2cf1f30f4f3b8bc20b4c3b005efcab1b3fef', '24346852b16c99de7d4d3fdcf0f8079734b16a']
# ROOT: ../.git/objects/3c
# DIRS: []
# FILES: ['8333d905a8bf6d6e09fd045bbd9151430c1d19']
# ROOT: ../.git/objects/4a
# DIRS: []
# FILES: ['94980972faf3df5e2dce438dc85969a51fb72b', '55c23a23fc0f478226c7dc8c18fbc112d23d39']
# ROOT: ../.git/objects/8b
# DIRS: []
# FILES: ['da45cfa0b81842580e6ac0688da450a8dc6a22']
# ROOT: ../.git/objects/a5
# DIRS: []
# FILES: ['5340d8b2ac8328947b921d90e8be630fea74b2', 'c68380589fb14e2c0c617cbe43c1ab05501c2d']
# ROOT: ../.git/hooks
# DIRS: []
# FILES: ['update.sample', 'push-to-checkout.sample', 'pre-applypatch.sample', 'pre-merge-commit.sample', 'applypatch-msg.sample', 'post-update.sample', 'prepare-commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'sendemail-validate.sample', 'pre-push.sample', 'commit-msg.sample']

# %% [markdown]
# ## Starting other programs (`subprocess`)
#
# Sometimes, you want to start some piece of software (a command line
# tool) from within your Python3 program, and collect the result. You
# could use a script for this, which starts the command line tool, and rus
# your Python3 script afterwards, but you can as well use Python3 for the
# whole setting. We only give a basic example:
#
#     import subprocess
#
#     result = subprocess.run(
#         ["pdflatex", "-interaction=nonstopmode", "file.tex"],
#         capture_output=True, # capture stdout and stderr output instead of printing
#         text=True, # returns output as string, not binary
#         check=True # raises an error if the command fails
#     )
#
#     print(result.stdout)
#
# ## Exercises
#
# **Exercise f** Apparently,
# `"muller@gmail.com; wrong-email; muller@yahoo.com"` only contains two
# valid email addresses. Use AI and `re` in order to produce and
# understand code, which separates the correct from the incorrect email
# addresses.
#
# **Exercise d** A bank manager has an idea: Interests should be computed
# daily (as usual), but rounded to cents (round up if last digit is 5 or
# above) at the end of the day. (So, sub-cents are not kept for computing
# the account balance.) Assume someone has invested 1 Euro on January 1st,
# 0 (birth of christ) with an interest rate of 5% per year. \* Compute the
# account balance *as usual*, i.e. keeping sub-cents at all days. \*
# Compute the account balance using the above strategy, i.e. ignoring
# sub-cents at the end of each day.
#
# **Exercise** Instead of `os.walk()`, we can also use the `pathlib`
# library. Find out how the equivalent of `os.walk()` works when using
# `pathlib`.
#
# **Exercise** Create some `txt`-files in the current working directory.
# Then, write a Pathon3 program that iterates through all such files,
# creates `all.txt`, where the content of all you `txt`files is appended.
# If `all.txt` already exists, the program should give a warning that this
# file is overridden.
#
# **Exercise** What is your age in seconds/minutes/hours/days/months?
#
# **Exercise** Below are some sales dates and quantities.
#
# - Write a function, with `start` and `end` as `datetime` as input, which
#   gives you the total amount of sales during this time. (You will need
#   to convert `date` as given in the data to `datetime`. Note that `<`,
#   `>`, `<=`, `>=`, `==` work for `datetime` as expected.)
# - Write a function, with a date `date` and a number days `days` as
#   input, which returns the average amount of sales per day during the
#   last `days` since `date`.

# %%
data = [
        ("2026-01-01", 120),
        ("2026-01-02", 135),
        ("2026-01-03", 128),
        ("2026-01-08", 150),
        ("2026-02-01", 210),
        ("2026-02-03", 215)]
